# %% [markdown]
# # Latest GW Player Picker Dashboard
#
# Use this notebook to shortlist players by position, inspect predicted points, and generate plots you can share with your league group.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

from latest_gw_tools import load_latest_outputs, load_gw_outputs
from other_funcs import get_best_11, get_best_11_noadj, get_owner_dict

sns.set_theme(style='whitegrid')
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)

# %%
# Leave TARGET_GW as None to auto-load latest available GW output.
TARGET_GW = None
TOP_N = 20
BACKTEST_YEAR = 26
EXPORT_FIGURES = False
FIG_DIR = Path('figures')

if EXPORT_FIGURES:
    FIG_DIR.mkdir(parents=True, exist_ok=True)

# %%
if TARGET_GW is None:
    latest_gw, pred_simple, pred_full, fixture_difficulty = load_latest_outputs()
else:
    latest_gw = TARGET_GW
    pred_simple, pred_full, fixture_difficulty = load_gw_outputs(TARGET_GW)

print(f'Loaded GW: {latest_gw}')
print(f'Players in simple output: {len(pred_simple):,}')
print(f'Players in full output: {len(pred_full):,}')
# Out:
# Loaded GW: 38
# Players in simple output: 842
# Players in full output: 842

# %%
df = pred_simple.copy()
if 'predicted_points_adj' not in df.columns:
    df['predicted_points_adj'] = df['predicted_points']

owner_dict = get_owner_dict()
owner_name_map = {str(int(k)): v for k, v in owner_dict.items()}
df['owner_name'] = df['owner'].fillna(-1).astype(int).astype(str).map(owner_name_map).fillna('Free Agent')

# Combine duplicate player rows (e.g., double gameweeks) into one row per player/team/position/owner.
group_cols = ['full_name', 'team', 'position', 'owner_name']
for col in ['predicted_points', 'predicted_points_adj', 'fixture_diff_index']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

agg_dict = {
    'predicted_points': 'sum',
    'predicted_points_adj': 'sum',
}
if 'fixture_diff_index' in df.columns:
    agg_dict['fixture_diff_index'] = 'mean'

df = (
    df.groupby(group_cols, as_index=False)
    .agg(agg_dict)
)

rank_col = 'predicted_points_adj'
df_sorted = df.sort_values(rank_col, ascending=False).reset_index(drop=True)
df_sorted.head(10)
# Out:
#                       full_name       team position owner_name  \
# 0                erling_haaland   Man City      FWD       Doug
# 1                 william_osula  Newcastle      FWD       Will
# 2                   jeremy_doku   Man City      MID      Lucas
# 3  gabriel_dos_santos_magalhaes    Arsenal      DEF       Will
# 4                william_saliba    Arsenal      DEF      Lucas
# 5               antoine_semenyo   Man City      MID       Will
# 6                 danny_welbeck   Brighton      FWD       Will
# 7             david_raya_martin    Arsenal       GK       Dave
# 8            dominik_szoboszlai  Liverpool      MID       Dave
# 9                   bukayo_saka    Arsenal      MID       Will
#
#    predicted_points  predicted_points_adj  fixture_diff_index
# 0          5.432718             10.027148            1.845696
# 1          3.722895              7.445791            2.000000
# 2          4.878831              7.133764            1.462187
# 3          3.923690              6.537303            1.666111
# 4          3.406269              5.675221            1.666111
# 5          3.824796              5.592568            1.462187
# 6          2.751983              5.503966            2.000000
# 7          4.030086              5.476783            1.358974
# 8          4.366548              5.331112            1.220898
# 9          4.177743              4.994774            1.195568

# %%
## Position Shortlists

# %%
show_cols = ['full_name', 'team', 'owner_name', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']
position_lists = {}

for pos in ['GK', 'DEF', 'MID', 'FWD']:
    pos_df = (
        df_sorted
        .query('position == @pos')
        .loc[:, show_cols]
        .head(TOP_N)
        .reset_index(drop=True)
    )
    position_lists[pos] = pos_df
    print(f'\nTop {TOP_N} {pos}')
    display(pos_df)
# Out:
# Top 20 GK
#                    full_name            team  owner_name  predicted_points  \
# 0          david_raya_martin         Arsenal        Dave          4.030086
# 1                robin_roefs      Sunderland        Rory          2.901001
# 2                karl_darlow           Leeds  Free Agent          3.003800
# 3       gianluigi_donnarumma        Man City       Lucas          3.815688
# 4             mads_hermansen        West Ham       Lucas          2.644344
# 5                 bernd_leno          Fulham        Doug          3.152972
# 6                  matz_sels   Nott'm Forest  Free Agent          2.922774
# 7                  nick_pope       Newcastle  Free Agent          2.945845
# 8              senne_lammens         Man Utd        Rory          3.131950
# 9            bart_verbruggen        Brighton        Will          3.084774
# 10            dorde_petrovic     Bournemouth  Free Agent          3.109954
# 11           jordan_pickford         Everton        Doug          2.928035
# 12         caoimhin_kelleher       Brentford        Dave          3.035159
# 13  emiliano_martinez_romero     Aston Villa  Free Agent          3.132733
# 14            dean_henderson  Crystal Palace      Marcus          2.659980
# 15            antonin_kinsky           Spurs  Free Agent          2.595353
# 16           martin_dubravka         Burnley  Free Agent          1.497830
# 17      robert_lynch_sanchez         Chelsea      Marcus          1.962736
# 18       jose_malheiro_de_sa          Wolves  Free Agent          1.414538
# 19            daniel_bentley          Wolves  Free Agent          1.307793
#
#     predicted_points_adj  fixture_diff_index
# 0               5.476783            1.358974
# 1               4.165540            1.435897
# 2               4.031857            1.342252
# 3               3.516501            0.921590
# 4               3.323363            1.256782
# 5               3.247878            1.030100
# 6               3.072660            1.051282
# 7               3.014812            1.023411
# 8               2.892194            0.923449
# 9               2.888752            0.936455
# 10              2.237410            0.719435
# 11              1.932438            0.659978
# 12              1.624165            0.535117
# 13              1.566367            0.500000
# 14              1.558821            0.586027
# 15              1.297676            0.500000
# 16              1.200045            0.801189
# 17              1.187415            0.604980
# 18              1.182724            0.836120
# 19              1.093473            0.836120
# Top 20 DEF
#                        full_name         team  owner_name  predicted_points  \
# 0   gabriel_dos_santos_magalhaes      Arsenal        Will          3.923690
# 1                 william_saliba      Arsenal       Lucas          3.406269
# 2                     marc_guehi     Man City      Marcus          3.259588
# 3             riccardo_calafiori      Arsenal  Free Agent          2.334076
# 4                  matheus_nunes     Man City       Lucas          2.665044
# 5                virgil_van_dijk    Liverpool      Marcus          3.168791
# 6                  nordi_mukiele   Sunderland  Free Agent          2.718155
# 7                  nico_o'reilly     Man City        Doug          2.578357
# 8             abdukodir_khusanov     Man City        Doug          2.566832
# 9                james_tarkowski      Everton      Marcus          3.253281
# 10            myles_lewis_skelly      Arsenal  Free Agent          1.986858
# 11                benjamin_white      Arsenal  Free Agent          1.935492
# 12                ferdi_kadioglu     Brighton        Dave          3.312648
# 13               adrien_truffert  Bournemouth        Dave          3.444566
# 14           marcos_senesi_baron  Bournemouth  Free Agent          3.429610
# 15                    jaka_bijol        Leeds  Free Agent          2.647760
# 16                   sven_botman    Newcastle  Free Agent          2.711087
# 17            jan_paul_van_hecke     Brighton      Marcus          2.921776
# 18         el_hadji_malick_diouf     West Ham  Free Agent          2.423875
# 19                  james_justin        Leeds  Free Agent          2.605484
#
#     predicted_points_adj  fixture_diff_index
# 0               6.537303            1.666111
# 1               5.675221            1.666111
# 2               4.298865            1.318837
# 3               3.888829            1.666111
# 4               3.514759            1.318837
# 5               3.510723            1.107906
# 6               3.472869            1.277657
# 7               3.400433            1.318837
# 8               3.385233            1.318837
# 9               3.319066            1.020221
# 10              3.310325            1.666111
# 11              3.224744            1.666111
# 12              3.179270            0.959737
# 13              3.174119            0.921486
# 14              3.160337            0.921486
# 15              2.824911            1.066906
# 16              2.816063            1.038721
# 17              2.804136            0.959737
# 18              2.786868            1.149757
# 19              2.779806            1.066906
# Top 20 MID
#                                   full_name       team  owner_name  \
# 0                               jeremy_doku   Man City       Lucas
# 1                           antoine_semenyo   Man City        Will
# 2                        dominik_szoboszlai  Liverpool        Dave
# 3                               bukayo_saka    Arsenal        Will
# 4                    bruno_borges_fernandes    Man Utd        Will
# 5                              pascal_gross   Brighton        Doug
# 6                          jack_hinshelwood   Brighton        Will
# 7                                phil_foden   Man City  Free Agent
# 8                              rayan_cherki   Man City       Lucas
# 9   bernardo_mota_veiga_de_carvalho_e_silva   Man City        Doug
# 10                         leandro_trossard    Arsenal        Dave
# 11                    kiernan_dewsbury_hall    Everton       Lucas
# 12                            iliman_ndiaye    Everton      Marcus
# 13                            omar_marmoush   Man City  Free Agent
# 14                      alexis_mac_allister  Liverpool  Free Agent
# 15                             ethan_ampadu      Leeds  Free Agent
# 16                              declan_rice    Arsenal        Rory
# 17                           yankuba_minteh   Brighton        Dave
# 18                               cody_gakpo  Liverpool        Doug
# 19                             eberechi_eze    Arsenal        Doug
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           4.878831              7.133764            1.462187
# 1           3.824796              5.592568            1.462187
# 2           4.366548              5.331112            1.220898
# 3           4.177743              4.994774            1.195568
# 4           5.494335              4.811245            0.875674
# 5           4.137842              4.692665            1.134085
# 6           4.084694              4.632391            1.134085
# 7           3.140207              4.591571            1.462187
# 8           3.068020              4.486019            1.462187
# 9           3.035215              4.438052            1.462187
# 10          3.504131              4.189426            1.195568
# 11          3.304983              4.174719            1.263159
# 12          3.160836              3.992639            1.263159
# 13          2.701467              3.950050            1.462187
# 14          3.221205              3.932765            1.220898
# 15          2.982138              3.890284            1.304528
# 16          3.250076              3.885686            1.195568
# 17          3.424431              3.883596            1.134085
# 18          3.177734              3.879690            1.220898
# 19          3.172653              3.793121            1.195568
# Top 20 FWD
#                            full_name           team  owner_name  \
# 0                     erling_haaland       Man City        Doug
# 1                      william_osula      Newcastle        Will
# 2                      danny_welbeck       Brighton        Will
# 3                     nick_woltemade      Newcastle  Free Agent
# 4                    viktor_gyokeres        Arsenal        Doug
# 5                      ollie_watkins    Aston Villa        Rory
# 6   igor_thiago_nascimento_rodrigues      Brentford      Marcus
# 7                      brian_brobbey     Sunderland        Doug
# 8                        kai_havertz        Arsenal  Free Agent
# 9          igor_jesus_maciel_da_cruz  Nott'm Forest      Marcus
# 10            richarlison_de_andrade          Spurs        Rory
# 11                    benjamin_sesko        Man Utd        Dave
# 12                       yoane_wissa      Newcastle  Free Agent
# 13             dominic_calvert_lewin          Leeds        Dave
# 14                    alexander_isak      Liverpool       Lucas
# 15                     junior_kroupi    Bournemouth        Dave
# 16  norberto_bercique_gomes_betuncal        Everton       Lucas
# 17                     thierno_barry        Everton  Free Agent
# 18                     taiwo_awoniyi  Nott'm Forest  Free Agent
# 19     joao_pedro_junqueira_de_jesus        Chelsea        Will
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           5.432718             10.027148            1.845696
# 1           3.722895              7.445791            2.000000
# 2           2.751983              5.503966            2.000000
# 3           2.487021              4.974042            2.000000
# 4           3.435033              4.848859            1.411590
# 5           4.190748              4.480128            1.069052
# 6           3.643561              4.187597            1.149314
# 7           3.164392              3.965536            1.253175
# 8           2.506189              3.537712            1.411590
# 9           3.609686              3.510378            0.972488
# 10          3.495739              3.191958            0.913100
# 11          2.269682              3.120283            1.374766
# 12          1.515785              3.031570            2.000000
# 13          4.086411              3.004564            0.735257
# 14          2.346916              2.928704            1.247895
# 15          3.629177              2.855651            0.786859
# 16          2.338848              2.780762            1.188945
# 17          2.328273              2.768190            1.188945
# 18          2.842133              2.763941            0.972488
# 19          2.457631              2.707703            1.101753

# %%
show_cols = ['full_name', 'team', 'position', 'owner_name', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']
positions = ['GK', 'DEF', 'MID', 'FWD']

for pos in positions:
    doug_pos = (
        df_sorted
        .query('position == @pos and owner_name == "Doug"')
        .loc[:, show_cols]
    )

    free_agent_pos = (
        df_sorted
        .query('position == @pos and owner_name == "Free Agent"')
        .loc[:, show_cols]
        .head(20)
    )

    combined_pos = pd.concat([doug_pos, free_agent_pos], ignore_index=True)

    print(f'\n{pos}: Doug + Top Free Agents')
    display(combined_pos)
# Out:
# GK: Doug + Top Free Agents
#                      full_name           team position  owner_name  \
# 0                   bernd_leno         Fulham       GK        Doug
# 1              jordan_pickford        Everton       GK        Doug
# 2                  karl_darlow          Leeds       GK  Free Agent
# 3                    matz_sels  Nott'm Forest       GK  Free Agent
# 4                    nick_pope      Newcastle       GK  Free Agent
# 5               dorde_petrovic    Bournemouth       GK  Free Agent
# 6     emiliano_martinez_romero    Aston Villa       GK  Free Agent
# 7               antonin_kinsky          Spurs       GK  Free Agent
# 8              martin_dubravka        Burnley       GK  Free Agent
# 9          jose_malheiro_de_sa         Wolves       GK  Free Agent
# 10              daniel_bentley         Wolves       GK  Free Agent
# 11                   max_weiss        Burnley       GK  Free Agent
# 12             freddie_woodman      Liverpool       GK  Free Agent
# 13        giorgi_mamardashvili      Liverpool       GK  Free Agent
# 14             filip_jorgensen        Chelsea       GK  Free Agent
# 15   ederson_santana_de_moraes       Man City       GK  Free Agent
# 16         lucas_estella_perri          Leeds       GK  Free Agent
# 17              aaron_ramsdale      Newcastle       GK  Free Agent
# 18                 andre_onana        Man Utd       GK  Free Agent
# 19  kepa_arrizabalaga_revuelta        Arsenal       GK  Free Agent
# 20        stefan_ortega_moreno  Nott'm Forest       GK  Free Agent
# 21              altay_bayindir        Man Utd       GK  Free Agent
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           3.152972              3.247878            1.030100
# 1           2.928035              1.932438            0.659978
# 2           3.003800              4.031857            1.342252
# 3           2.922774              3.072660            1.051282
# 4           2.945845              3.014812            1.023411
# 5           3.109954              2.237410            0.719435
# 6           3.132733              1.566367            0.500000
# 7           2.595353              1.297676            0.500000
# 8           1.497830              1.200045            0.801189
# 9           1.414538              1.182724            0.836120
# 10          1.307793              1.093473            0.836120
# 11          1.353988              1.084800            0.801189
# 12          1.422819              0.977882            0.687285
# 13          1.390911              0.955952            0.687285
# 14          1.048294              0.634196            0.604980
# 15          0.640576              0.590349            0.921590
# 16          0.422073              0.566529            1.342252
# 17          0.499798              0.511499            1.023411
# 18          0.550788              0.508625            0.923449
# 19          0.365117              0.496184            1.358974
# 20          0.465300              0.489161            1.051282
# 21          0.508057              0.469165            0.923449
# DEF: Doug + Top Free Agents
#                   full_name         team position  owner_name  \
# 0             nico_o'reilly     Man City      DEF        Doug
# 1        abdukodir_khusanov     Man City      DEF        Doug
# 2                james_hill  Bournemouth      DEF        Doug
# 3          timothy_castagne       Fulham      DEF        Doug
# 4        keane_lewis_potter    Brentford      DEF        Doug
# 5        riccardo_calafiori      Arsenal      DEF  Free Agent
# 6             nordi_mukiele   Sunderland      DEF  Free Agent
# 7        myles_lewis_skelly      Arsenal      DEF  Free Agent
# 8            benjamin_white      Arsenal      DEF  Free Agent
# 9       marcos_senesi_baron  Bournemouth      DEF  Free Agent
# 10               jaka_bijol        Leeds      DEF  Free Agent
# 11              sven_botman    Newcastle      DEF  Free Agent
# 12    el_hadji_malick_diouf     West Ham      DEF  Free Agent
# 13             james_justin        Leeds      DEF  Free Agent
# 14   santiago_ignacio_bueno       Wolves      DEF  Free Agent
# 15                trai_hume   Sunderland      DEF  Free Agent
# 16  konstantinos_mavropanos     West Ham      DEF  Free Agent
# 17           piero_hincapie      Arsenal      DEF  Free Agent
# 18         reinildo_mandava   Sunderland      DEF  Free Agent
# 19            omar_alderete   Sunderland      DEF  Free Agent
# 20                 dan_burn    Newcastle      DEF  Free Agent
# 21                luke_shaw      Man Utd      DEF  Free Agent
# 22              axel_disasi     West Ham      DEF  Free Agent
# 23             jake_o'brien      Everton      DEF  Free Agent
# 24                joe_rodon        Leeds      DEF  Free Agent
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           2.578357              3.400433            1.318837
# 1           2.566832              3.385233            1.318837
# 2           2.699114              2.487195            0.921486
# 3           2.571741              2.014072            0.783155
# 4           2.643698              1.982190            0.749779
# 5           2.334076              3.888829            1.666111
# 6           2.718155              3.472869            1.277657
# 7           1.986858              3.310325            1.666111
# 8           1.935492              3.224744            1.666111
# 9           3.429610              3.160337            0.921486
# 10          2.647760              2.824911            1.066906
# 11          2.711087              2.816063            1.038721
# 12          2.423875              2.786868            1.149757
# 13          2.605484              2.779806            1.066906
# 14          2.484297              2.742305            1.103855
# 15          2.121362              2.710373            1.277657
# 16          2.308582              2.654308            1.149757
# 17          1.543595              2.571801            1.666111
# 18          1.919629              2.452628            1.277657
# 19          1.917676              2.450132            1.277657
# 20          2.352007              2.443080            1.038721
# 21          2.695405              2.399400            0.890181
# 22          2.029447              2.333371            1.149757
# 23          2.241147              2.286466            1.020221
# 24          2.083926              2.223353            1.066906
# MID: Doug + Top Free Agents
#                                   full_name           team position  \
# 0                              pascal_gross       Brighton      MID
# 1   bernardo_mota_veiga_de_carvalho_e_silva       Man City      MID
# 2                                cody_gakpo      Liverpool      MID
# 3                              eberechi_eze        Arsenal      MID
# 4                        morgan_gibbs_white  Nott'm Forest      MID
# 5                                phil_foden       Man City      MID
# 6                             omar_marmoush       Man City      MID
# 7                       alexis_mac_allister      Liverpool      MID
# 8                              ethan_ampadu          Leeds      MID
# 9                           elliot_anderson  Nott'm Forest      MID
# 10                           dango_ouattara      Brentford      MID
# 11                              enzo_le_fee     Sunderland      MID
# 12               joao_victor_gomes_da_silva         Wolves      MID
# 13                         mikkel_damsgaard      Brentford      MID
# 14                             curtis_jones      Liverpool      MID
# 15         matheus_santos_carneiro_da_cunha        Man Utd      MID
# 16                          martin_odegaard        Arsenal      MID
# 17                savio_moreira_de_oliveira       Man City      MID
# 18             andre_trindade_da_costa_neto         Wolves      MID
# 19              rayan_vitor_simplicio_rocha    Bournemouth      MID
# 20                                tanaka_ao          Leeds      MID
# 21                             granit_xhaka     Sunderland      MID
# 22                              anton_stach          Leeds      MID
# 23                               mathys_tel          Spurs      MID
# 24                           mathias_jensen      Brentford      MID
#
#     owner_name  predicted_points  predicted_points_adj  fixture_diff_index
# 0         Doug          4.137842              4.692665            1.134085
# 1         Doug          3.035215              4.438052            1.462187
# 2         Doug          3.177734              3.879690            1.220898
# 3         Doug          3.172653              3.793121            1.195568
# 4         Doug          3.499655              3.635734            1.038884
# 5   Free Agent          3.140207              4.591571            1.462187
# 6   Free Agent          2.701467              3.950050            1.462187
# 7   Free Agent          3.221205              3.932765            1.220898
# 8   Free Agent          2.982138              3.890284            1.304528
# 9   Free Agent          3.631419              3.772622            1.038884
# 10  Free Agent          3.594467              3.531536            0.982492
# 11  Free Agent          3.501782              3.473582            0.991947
# 12  Free Agent          2.550104              3.441766            1.349657
# 13  Free Agent          3.455196              3.394703            0.982492
# 14  Free Agent          2.699556              3.295884            1.220898
# 15  Free Agent          3.682330              3.224520            0.875674
# 16  Free Agent          2.682933              3.207628            1.195568
# 17  Free Agent          2.186532              3.197119            1.462187
# 18  Free Agent          2.361424              3.187112            1.349657
# 19  Free Agent          3.617532              3.182970            0.879873
# 20  Free Agent          2.397337              3.127394            1.304528
# 21  Free Agent          3.069066              3.044350            0.991947
# 22  Free Agent          2.325195              3.033283            1.304528
# 23  Free Agent          3.112285              3.009265            0.966899
# 24  Free Agent          3.023840              2.970900            0.982492
# FWD: Doug + Top Free Agents
#                               full_name           team position  owner_name  \
# 0                        erling_haaland       Man City      FWD        Doug
# 1                       viktor_gyokeres        Arsenal      FWD        Doug
# 2                         brian_brobbey     Sunderland      FWD        Doug
# 3                        nick_woltemade      Newcastle      FWD  Free Agent
# 4                           kai_havertz        Arsenal      FWD  Free Agent
# 5                           yoane_wissa      Newcastle      FWD  Free Agent
# 6                         thierno_barry        Everton      FWD  Free Agent
# 7                         taiwo_awoniyi  Nott'm Forest      FWD  Free Agent
# 8                           mateus_mane         Wolves      FWD  Free Agent
# 9   francisco_evanilson_de_lima_barbosa    Bournemouth      FWD  Free Agent
# 10                    randal_kolo_muani          Spurs      FWD  Free Agent
# 11                           chris_wood  Nott'm Forest      FWD  Free Agent
# 12                           liam_delap        Chelsea      FWD  Free Agent
# 13                    eli_junior_kroupi    Bournemouth      FWD  Free Agent
# 14                        zian_flemming        Burnley      FWD  Free Agent
# 15                       joshua_zirkzee        Man Utd      FWD  Free Agent
# 16                charalampos_kostoulas       Brighton      FWD  Free Agent
# 17                 valentin_castellanos       West Ham      FWD  Free Agent
# 18                        wilson_isidor     Sunderland      FWD  Free Agent
# 19                         hugo_ekitike      Liverpool      FWD  Free Agent
# 20               rodrigo_muniz_carvalho         Fulham      FWD  Free Agent
# 21               raul_jimenez_rodriguez         Fulham      FWD  Free Agent
# 22        pablo_felipe_pereira_de_jesus       West Ham      FWD  Free Agent
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           5.432718             10.027148            1.845696
# 1           3.435033              4.848859            1.411590
# 2           3.164392              3.965536            1.253175
# 3           2.487021              4.974042            2.000000
# 4           2.506189              3.537712            1.411590
# 5           1.515785              3.031570            2.000000
# 6           2.328273              2.768190            1.188945
# 7           2.842133              2.763941            0.972488
# 8           3.822151              2.679185            0.700963
# 9           3.130405              2.463187            0.786859
# 10          2.673003              2.440717            0.913100
# 11          2.496257              2.427582            0.972488
# 12          2.196048              2.419503            1.101753
# 13          2.809595              2.210755            0.786859
# 14          3.201070              2.101733            0.656572
# 15          1.465298              2.014442            1.374766
# 16          0.854028              1.708056            2.000000
# 17          2.888932              1.571587            0.544003
# 18          1.244661              1.559778            1.253175
# 19          1.096476              1.368286            1.247895
# 20          1.860859              1.336119            0.718012
# 21          1.855281              1.332114            0.718012
# 22          2.438759              1.326691            0.544003

# %%
# A compact shortlist view you can screenshot/share.
shortlist = pd.concat(
    [
        position_lists[pos].assign(position=pos)
        for pos in ['GK', 'DEF', 'MID', 'FWD']
    ],
    ignore_index=True,
)

shortlist = shortlist[[
    'position', 'full_name', 'team', 'owner_name',
    'predicted_points', 'predicted_points_adj', 'fixture_diff_index'
 ]]
shortlist.head(40)
# Out:
#    position                     full_name            team  owner_name  \
# 0        GK             david_raya_martin         Arsenal        Dave
# 1        GK                   robin_roefs      Sunderland        Rory
# 2        GK                   karl_darlow           Leeds  Free Agent
# 3        GK          gianluigi_donnarumma        Man City       Lucas
# 4        GK                mads_hermansen        West Ham       Lucas
# 5        GK                    bernd_leno          Fulham        Doug
# 6        GK                     matz_sels   Nott'm Forest  Free Agent
# 7        GK                     nick_pope       Newcastle  Free Agent
# 8        GK                 senne_lammens         Man Utd        Rory
# 9        GK               bart_verbruggen        Brighton        Will
# 10       GK                dorde_petrovic     Bournemouth  Free Agent
# 11       GK               jordan_pickford         Everton        Doug
# 12       GK             caoimhin_kelleher       Brentford        Dave
# 13       GK      emiliano_martinez_romero     Aston Villa  Free Agent
# 14       GK                dean_henderson  Crystal Palace      Marcus
# 15       GK                antonin_kinsky           Spurs  Free Agent
# 16       GK               martin_dubravka         Burnley  Free Agent
# 17       GK          robert_lynch_sanchez         Chelsea      Marcus
# 18       GK           jose_malheiro_de_sa          Wolves  Free Agent
# 19       GK                daniel_bentley          Wolves  Free Agent
# 20      DEF  gabriel_dos_santos_magalhaes         Arsenal        Will
# 21      DEF                william_saliba         Arsenal       Lucas
# 22      DEF                    marc_guehi        Man City      Marcus
# 23      DEF            riccardo_calafiori         Arsenal  Free Agent
# 24      DEF                 matheus_nunes        Man City       Lucas
# 25      DEF               virgil_van_dijk       Liverpool      Marcus
# 26      DEF                 nordi_mukiele      Sunderland  Free Agent
# 27      DEF                 nico_o'reilly        Man City        Doug
# 28      DEF            abdukodir_khusanov        Man City        Doug
# 29      DEF               james_tarkowski         Everton      Marcus
# 30      DEF            myles_lewis_skelly         Arsenal  Free Agent
# 31      DEF                benjamin_white         Arsenal  Free Agent
# 32      DEF                ferdi_kadioglu        Brighton        Dave
# 33      DEF               adrien_truffert     Bournemouth        Dave
# 34      DEF           marcos_senesi_baron     Bournemouth  Free Agent
# 35      DEF                    jaka_bijol           Leeds  Free Agent
# 36      DEF                   sven_botman       Newcastle  Free Agent
# 37      DEF            jan_paul_van_hecke        Brighton      Marcus
# 38      DEF         el_hadji_malick_diouf        West Ham  Free Agent
# 39      DEF                  james_justin           Leeds  Free Agent
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           4.030086              5.476783            1.358974
# 1           2.901001              4.165540            1.435897
# 2           3.003800              4.031857            1.342252
# 3           3.815688              3.516501            0.921590
# 4           2.644344              3.323363            1.256782
# 5           3.152972              3.247878            1.030100
# 6           2.922774              3.072660            1.051282
# 7           2.945845              3.014812            1.023411
# 8           3.131950              2.892194            0.923449
# 9           3.084774              2.888752            0.936455
# 10          3.109954              2.237410            0.719435
# 11          2.928035              1.932438            0.659978
# 12          3.035159              1.624165            0.535117
# 13          3.132733              1.566367            0.500000
# 14          2.659980              1.558821            0.586027
# 15          2.595353              1.297676            0.500000
# 16          1.497830              1.200045            0.801189
# 17          1.962736              1.187415            0.604980
# 18          1.414538              1.182724            0.836120
# 19          1.307793              1.093473            0.836120
# 20          3.923690              6.537303            1.666111
# 21          3.406269              5.675221            1.666111
# 22          3.259588              4.298865            1.318837
# 23          2.334076              3.888829            1.666111
# 24          2.665044              3.514759            1.318837
# 25          3.168791              3.510723            1.107906
# 26          2.718155              3.472869            1.277657
# 27          2.578357              3.400433            1.318837
# 28          2.566832              3.385233            1.318837
# 29          3.253281              3.319066            1.020221
# 30          1.986858              3.310325            1.666111
# 31          1.935492              3.224744            1.666111
# 32          3.312648              3.179270            0.959737
# 33          3.444566              3.174119            0.921486
# 34          3.429610              3.160337            0.921486
# 35          2.647760              2.824911            1.066906
# 36          2.711087              2.816063            1.038721
# 37          2.921776              2.804136            0.959737
# 38          2.423875              2.786868            1.149757
# 39          2.605484              2.779806            1.066906

# %%
## Team Selection Helpers

# %%
formation_adj, best_11_adj = get_best_11(df_sorted)
formation_raw, best_11_raw = get_best_11_noadj(df_sorted)

print(f'Best XI (adj) formation: {formation_adj}')
display(best_11_adj[['full_name', 'position', 'team', 'owner_name', 'predicted_points', 'predicted_points_adj']])

print(f'Best XI (raw) formation: {formation_raw}')
display(best_11_raw[['full_name', 'position', 'team', 'owner_name', 'predicted_points']])
# Out:
# Best XI (adj) formation: {'GK': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
#                        full_name position       team owner_name  \
# 8                 erling_haaland      FWD   Man City       Doug
# 9                  william_osula      FWD  Newcastle       Will
# 4                    jeremy_doku      MID   Man City      Lucas
# 1   gabriel_dos_santos_magalhaes      DEF    Arsenal       Will
# 2                 william_saliba      DEF    Arsenal      Lucas
# 5                antoine_semenyo      MID   Man City       Will
# 10                 danny_welbeck      FWD   Brighton       Will
# 0              david_raya_martin       GK    Arsenal       Dave
# 6             dominik_szoboszlai      MID  Liverpool       Dave
# 7                    bukayo_saka      MID    Arsenal       Will
# 3                     marc_guehi      DEF   Man City     Marcus
#
#     predicted_points  predicted_points_adj
# 8           5.432718             10.027148
# 9           3.722895              7.445791
# 4           4.878831              7.133764
# 1           3.923690              6.537303
# 2           3.406269              5.675221
# 5           3.824796              5.592568
# 10          2.751983              5.503966
# 0           4.030086              5.476783
# 6           4.366548              5.331112
# 7           4.177743              4.994774
# 3           3.259588              4.298865
# Best XI (raw) formation: {'GK': 1, 'DEF': 3, 'MID': 5, 'FWD': 2}
#                        full_name position       team owner_name  \
# 8         bruno_borges_fernandes      MID    Man Utd       Will
# 9                 erling_haaland      FWD   Man City       Doug
# 4                    jeremy_doku      MID   Man City      Lucas
# 6             dominik_szoboszlai      MID  Liverpool       Dave
# 7                    bukayo_saka      MID    Arsenal       Will
# 0              david_raya_martin       GK    Arsenal       Dave
# 1   gabriel_dos_santos_magalhaes      DEF    Arsenal       Will
# 5                antoine_semenyo      MID   Man City       Will
# 10                 william_osula      FWD  Newcastle       Will
# 2                 william_saliba      DEF    Arsenal      Lucas
# 3                     marc_guehi      DEF   Man City     Marcus
#
#     predicted_points
# 8           5.494335
# 9           5.432718
# 4           4.878831
# 6           4.366548
# 7           4.177743
# 0           4.030086
# 1           3.923690
# 5           3.824796
# 10          3.722895
# 2           3.406269
# 3           3.259588

# %%
doug_pool = df_sorted.query('owner_name == "Doug"').copy()
doug_formation, doug_best_11 = get_best_11(doug_pool)

print(f"Doug Best XI formation: {doug_formation['DEF']}-{doug_formation['MID']}-{doug_formation['FWD']}")
display(
    doug_best_11[
        ['full_name', 'position', 'team', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']
    ].sort_values(['position', 'predicted_points_adj'], ascending=[True, False]).reset_index(drop=True)
)

bench_key_cols = ['full_name', 'team', 'position']
bench_keys = set(
    tuple(row) for row in doug_best_11[bench_key_cols].drop_duplicates().itertuples(index=False, name=None)
)
bench_players = (
    doug_pool[
        ~doug_pool[bench_key_cols].apply(tuple, axis=1).isin(bench_keys)
    ][['full_name', 'position', 'team', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']]
    .sort_values('predicted_points_adj', ascending=False)
    .reset_index(drop=True)
)

print('Doug Bench Players:')
display(bench_players)
# Out:
# Doug Best XI formation: 3-4-3
#                                   full_name position         team  \
# 0                             nico_o'reilly      DEF     Man City
# 1                        abdukodir_khusanov      DEF     Man City
# 2                                james_hill      DEF  Bournemouth
# 3                            erling_haaland      FWD     Man City
# 4                           viktor_gyokeres      FWD      Arsenal
# 5                             brian_brobbey      FWD   Sunderland
# 6                                bernd_leno       GK       Fulham
# 7                              pascal_gross      MID     Brighton
# 8   bernardo_mota_veiga_de_carvalho_e_silva      MID     Man City
# 9                                cody_gakpo      MID    Liverpool
# 10                             eberechi_eze      MID      Arsenal
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           2.578357              3.400433            1.318837
# 1           2.566832              3.385233            1.318837
# 2           2.699114              2.487195            0.921486
# 3           5.432718             10.027148            1.845696
# 4           3.435033              4.848859            1.411590
# 5           3.164392              3.965536            1.253175
# 6           3.152972              3.247878            1.030100
# 7           4.137842              4.692665            1.134085
# 8           3.035215              4.438052            1.462187
# 9           3.177734              3.879690            1.220898
# 10          3.172653              3.793121            1.195568
# Doug Bench Players:
#             full_name position           team  predicted_points  \
# 0  morgan_gibbs_white      MID  Nott'm Forest          3.499655
# 1    timothy_castagne      DEF         Fulham          2.571741
# 2  keane_lewis_potter      DEF      Brentford          2.643698
# 3     jordan_pickford       GK        Everton          2.928035
#
#    predicted_points_adj  fixture_diff_index
# 0              3.635734            1.038884
# 1              2.014072            0.783155
# 2              1.982190            0.749779
# 3              1.932438            0.659978

# %%
owner_summary_rows = []
fa_formation = None
fa_best_11 = pd.DataFrame()

for owner_name in sorted(df_sorted['owner_name'].unique()):
    if owner_name == 'Free Agent':
        continue
    owner_df = df_sorted.query('owner_name == @owner_name').copy()
    if owner_df.empty:
        continue
    owner_formation, owner_best_11 = get_best_11(owner_df)
    owner_summary_rows.append({
        'owner_name': owner_name,
        'formation': f"{owner_formation['DEF']}-{owner_formation['MID']}-{owner_formation['FWD']}",
        'predicted_points_adj_sum': owner_best_11['predicted_points_adj'].sum(),
        'predicted_points_sum': owner_best_11['predicted_points'].sum(),
    })

# Add and show the best XI that can be built from free agents only.
free_agent_df = df_sorted.query('owner_name == "Free Agent"').copy()
if not free_agent_df.empty:
    fa_formation, fa_best_11 = get_best_11(free_agent_df)
    owner_summary_rows.append({
        'owner_name': 'Free Agent XI',
        'formation': f"{fa_formation['DEF']}-{fa_formation['MID']}-{fa_formation['FWD']}",
        'predicted_points_adj_sum': fa_best_11['predicted_points_adj'].sum(),
        'predicted_points_sum': fa_best_11['predicted_points'].sum(),
    })

owner_summary = pd.DataFrame(owner_summary_rows).sort_values('predicted_points_adj_sum', ascending=False)
display(owner_summary)

if fa_best_11.empty:
    print('No Free Agent XI available for this GW.')
else:
    print(f"Free Agent XI formation: {fa_formation['DEF']}-{fa_formation['MID']}-{fa_formation['FWD']}")
    display(
        fa_best_11[
            ['full_name', 'position', 'team', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']
        ].sort_values(['position', 'predicted_points_adj'], ascending=[True, False]).reset_index(drop=True)
    )
# Out:
#       owner_name formation  predicted_points_adj_sum  predicted_points_sum
# 5           Will     3-5-2                 50.411273             40.226351
# 1           Doug     3-4-3                 48.165810             36.552861
# 6  Free Agent XI     3-5-2                 43.352926             30.712536
# 2          Lucas     3-5-2                 43.164698             33.494102
# 0           Dave     3-4-3                 40.065920             37.110342
# 3         Marcus     4-4-2                 36.449473             34.251049
# 4           Rory     3-4-3                 32.125016             33.698995
# Free Agent XI formation: 3-5-2
#               full_name position           team  predicted_points  \
# 0    riccardo_calafiori      DEF        Arsenal          2.334076
# 1         nordi_mukiele      DEF     Sunderland          2.718155
# 2    myles_lewis_skelly      DEF        Arsenal          1.986858
# 3        nick_woltemade      FWD      Newcastle          2.487021
# 4           kai_havertz      FWD        Arsenal          2.506189
# 5           karl_darlow       GK          Leeds          3.003800
# 6            phil_foden      MID       Man City          3.140207
# 7         omar_marmoush      MID       Man City          2.701467
# 8   alexis_mac_allister      MID      Liverpool          3.221205
# 9          ethan_ampadu      MID          Leeds          2.982138
# 10      elliot_anderson      MID  Nott'm Forest          3.631419
#
#     predicted_points_adj  fixture_diff_index
# 0               3.888829            1.666111
# 1               3.472869            1.277657
# 2               3.310325            1.666111
# 3               4.974042            2.000000
# 4               3.537712            1.411590
# 5               4.031857            1.342252
# 6               4.591571            1.462187
# 7               3.950050            1.462187
# 8               3.932765            1.220898
# 9               3.890284            1.304528
# 10              3.772622            1.038884

# %%
fig, ax = plt.subplots(figsize=(8, 4))
plot_owner_summary = owner_summary.copy()

sns.barplot(
    data=plot_owner_summary,
    x='owner_name',
    y='predicted_points_adj_sum',
    hue='owner_name',
    legend=False,
    ax=ax,
    palette='tab10',
)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', padding=3, fontsize=9)

ax.set_title(f'Best XI Projected Points by Owner (GW {latest_gw})')
ax.set_xlabel('Owner')
ax.set_ylabel('Total projected points (adjusted)')
plt.xticks(rotation=0)
plt.tight_layout()

if EXPORT_FIGURES:
    fig.savefig(FIG_DIR / f'owner_best_xi_gw{latest_gw}.png', dpi=200)

# %% [markdown]
# ## Shareable Plots

# %%
plot_df = (
    df_sorted
    .groupby('position', group_keys=False)
    .head(10)
    .copy()
)

fig, ax = plt.subplots(figsize=(12, 7))
sns.barplot(
    data=plot_df.sort_values(['position', 'predicted_points_adj'], ascending=[True, False]),
    x='predicted_points_adj',
    y='full_name',
    hue='position',
    dodge=False,
    ax=ax,
    palette='Set2',
)
ax.set_title(f'Top 10 Players per Position by Adjusted Projection (GW {latest_gw})')
ax.set_xlabel('Predicted points (adjusted)')
ax.set_ylabel('Player')
plt.tight_layout()

if EXPORT_FIGURES:
    fig.savefig(FIG_DIR / f'top10_by_position_gw{latest_gw}.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(
    data=df_sorted,
    x='predicted_points',
    y='predicted_points_adj',
    hue='position',
    alpha=0.8,
    ax=ax,
    palette='Set1',
)
ax.plot([0, df_sorted['predicted_points'].max()], [0, df_sorted['predicted_points'].max()], linestyle='--', color='grey')
ax.set_title(f'Raw vs Adjusted Predicted Points (GW {latest_gw})')
ax.set_xlabel('Predicted points (raw)')
ax.set_ylabel('Predicted points (adjusted)')
plt.tight_layout()

if EXPORT_FIGURES:
    fig.savefig(FIG_DIR / f'raw_vs_adjusted_gw{latest_gw}.png', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.violinplot(
    data=df_sorted,
    x='position',
    y='predicted_points_adj',
    inner='quartile',
    hue='position',
    legend=False,
    ax=ax,
    palette='Pastel1',
)
ax.set_title(f'Projection Distribution by Position (GW {latest_gw})')
ax.set_xlabel('Position')
ax.set_ylabel('Predicted points (adjusted)')
plt.tight_layout()

if EXPORT_FIGURES:
    fig.savefig(FIG_DIR / f'distribution_by_position_gw{latest_gw}.png', dpi=200)

# %%
team_pos = (
    df_sorted
    .groupby(['team', 'position'], as_index=False)['predicted_points_adj']
    .sum()
)

team_total = team_pos.groupby('team', as_index=False)['predicted_points_adj'].sum()
top_teams = team_total.sort_values('predicted_points_adj', ascending=False).head(12)['team']
heat_df = team_pos[team_pos['team'].isin(top_teams)].pivot(index='team', columns='position', values='predicted_points_adj').fillna(0)
heat_df = heat_df[['GK', 'DEF', 'MID', 'FWD']]

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(heat_df, annot=True, fmt='.1f', cmap='YlGnBu', ax=ax)
ax.set_title(f'Team-Position Projection Heatmap (Top 12 Teams, GW {latest_gw})')
ax.set_xlabel('Position')
ax.set_ylabel('Team')
plt.tight_layout()

if EXPORT_FIGURES:
    fig.savefig(FIG_DIR / f'team_position_heatmap_gw{latest_gw}.png', dpi=200)

# %%
share_cols = ['full_name', 'position', 'team', 'owner_name', 'predicted_points', 'predicted_points_adj', 'fixture_diff_index']
share_table = df_sorted[share_cols].head(25).copy()
share_table
# Out:
#                                   full_name position         team  owner_name  \
# 0                            erling_haaland      FWD     Man City        Doug
# 1                             william_osula      FWD    Newcastle        Will
# 2                               jeremy_doku      MID     Man City       Lucas
# 3              gabriel_dos_santos_magalhaes      DEF      Arsenal        Will
# 4                            william_saliba      DEF      Arsenal       Lucas
# 5                           antoine_semenyo      MID     Man City        Will
# 6                             danny_welbeck      FWD     Brighton        Will
# 7                         david_raya_martin       GK      Arsenal        Dave
# 8                        dominik_szoboszlai      MID    Liverpool        Dave
# 9                               bukayo_saka      MID      Arsenal        Will
# 10                           nick_woltemade      FWD    Newcastle  Free Agent
# 11                          viktor_gyokeres      FWD      Arsenal        Doug
# 12                   bruno_borges_fernandes      MID      Man Utd        Will
# 13                             pascal_gross      MID     Brighton        Doug
# 14                         jack_hinshelwood      MID     Brighton        Will
# 15                               phil_foden      MID     Man City  Free Agent
# 16                             rayan_cherki      MID     Man City       Lucas
# 17                            ollie_watkins      FWD  Aston Villa        Rory
# 18  bernardo_mota_veiga_de_carvalho_e_silva      MID     Man City        Doug
# 19                               marc_guehi      DEF     Man City      Marcus
# 20                         leandro_trossard      MID      Arsenal        Dave
# 21         igor_thiago_nascimento_rodrigues      FWD    Brentford      Marcus
# 22                    kiernan_dewsbury_hall      MID      Everton       Lucas
# 23                              robin_roefs       GK   Sunderland        Rory
# 24                              karl_darlow       GK        Leeds  Free Agent
#
#     predicted_points  predicted_points_adj  fixture_diff_index
# 0           5.432718             10.027148            1.845696
# 1           3.722895              7.445791            2.000000
# 2           4.878831              7.133764            1.462187
# 3           3.923690              6.537303            1.666111
# 4           3.406269              5.675221            1.666111
# 5           3.824796              5.592568            1.462187
# 6           2.751983              5.503966            2.000000
# 7           4.030086              5.476783            1.358974
# 8           4.366548              5.331112            1.220898
# 9           4.177743              4.994774            1.195568
# 10          2.487021              4.974042            2.000000
# 11          3.435033              4.848859            1.411590
# 12          5.494335              4.811245            0.875674
# 13          4.137842              4.692665            1.134085
# 14          4.084694              4.632391            1.134085
# 15          3.140207              4.591571            1.462187
# 16          3.068020              4.486019            1.462187
# 17          4.190748              4.480128            1.069052
# 18          3.035215              4.438052            1.462187
# 19          3.259588              4.298865            1.318837
# 20          3.504131              4.189426            1.195568
# 21          3.643561              4.187597            1.149314
# 22          3.304983              4.174719            1.263159
# 23          2.901001              4.165540            1.435897
# 24          3.003800              4.031857            1.342252

# %%
if EXPORT_FIGURES:
    print(f'Saved figures to: {FIG_DIR.resolve()}')
else:
    print('Set EXPORT_FIGURES = True to save PNG charts for sharing.')
# Out:
# Set EXPORT_FIGURES = True to save PNG charts for sharing.

# %% [markdown]
# ## Historical Backtest: Predicted vs Actual (All GWs)

# %%
import re
import sys
import requests

sys.path.append(str(Path('..').resolve()))
from wrangle_data_funcs import clean_name

predictions_dir = Path('predictions')
pred_files = sorted(predictions_dir.glob('predicted_gw[0-9]*.csv'))

gw_file_pairs = []
for file_path in pred_files:
    if file_path.name.endswith('_simple.csv'):
        continue
    match = re.search(r'predicted_gw(\d+)\.csv$', file_path.name)
    if match:
        gw_file_pairs.append((int(match.group(1)), file_path))

gw_file_pairs = sorted(gw_file_pairs, key=lambda x: x[0])
print(f'Found GW prediction files: {len(gw_file_pairs)}')

bootstrap = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/', timeout=20).json()
name_by_element = {}
for elem in bootstrap['elements']:
    full_name = clean_name(f"{elem['first_name']}_{elem['second_name']}")
    name_by_element[elem['id']] = full_name

def load_actual_points_for_gw_from_api(gw):
    event_live = requests.get(f'https://fantasy.premierleague.com/api/event/{gw}/live/', timeout=20).json()
    rows = []
    for item in event_live.get('elements', []):
        element_id = item.get('id')
        full_name = name_by_element.get(element_id)
        if full_name is None:
            continue
        total_points = item.get('stats', {}).get('total_points', np.nan)
        rows.append({'full_name': full_name, 'actual_points': total_points})

    actual_gw_df = pd.DataFrame(rows)
    if actual_gw_df.empty:
        raise ValueError(f'No actual rows returned from FPL API for GW {gw}')

    return actual_gw_df

backtest_frames = []
skipped_gws = []
for gw, file_path in gw_file_pairs:
    pred_gw_df = pd.read_csv(file_path)
    if 'predicted_points_adj' not in pred_gw_df.columns:
        pred_gw_df['predicted_points_adj'] = pred_gw_df['predicted_points']

    try:
        actual_gw_df = load_actual_points_for_gw_from_api(gw)
    except Exception as exc:
        skipped_gws.append((gw, str(exc)))
        continue

    merged = pred_gw_df.merge(actual_gw_df, on='full_name', how='inner')
    if merged.empty:
        skipped_gws.append((gw, 'No name overlap between prediction and actual files'))
        continue

    merged['gw'] = gw
    backtest_frames.append(
        merged[['gw', 'full_name', 'position', 'team', 'predicted_points', 'predicted_points_adj', 'actual_points']]
    )

backtest_df = pd.concat(backtest_frames, ignore_index=True) if backtest_frames else pd.DataFrame()
print(f'Total merged player-GW rows: {len(backtest_df):,}')
if skipped_gws:
    print(f'Skipped GWs: {[gw for gw, _ in skipped_gws]}')

if not backtest_df.empty:
    backtest_df['error_raw'] = backtest_df['predicted_points'] - backtest_df['actual_points']
    backtest_df['error_adj'] = backtest_df['predicted_points_adj'] - backtest_df['actual_points']
    backtest_df['abs_error_raw'] = backtest_df['error_raw'].abs()
    backtest_df['abs_error_adj'] = backtest_df['error_adj'].abs()

backtest_df.head()
# Out:
# Found GW prediction files: 37
# Total merged player-GW rows: 27,665
# Skipped GWs: [38]
#    gw          full_name position       team  predicted_points  \
# 0   2    aaron_anselmino      DEF    Chelsea          0.739413
# 1   2       aaron_hickey      DEF  Brentford          0.729099
# 2   2     aaron_ramsdale       GK  Newcastle          0.865016
# 3   2       aaron_ramsey      MID    Burnley          0.665792
# 4   2  aaron_wan_bissaka      DEF   West Ham          2.558778
#
#    predicted_points_adj  actual_points  error_raw  error_adj  abs_error_raw  \
# 0              6.059800              0   0.739413   6.059800       0.739413
# 1              0.975531              1  -0.270901  -0.024469       0.270901
# 2              2.491246              0   0.865016   2.491246       0.865016
# 3              0.547374              0   0.665792   0.547374       0.665792
# 4              1.878468              0   2.558778   1.878468       2.558778
#
#    abs_error_adj
# 0       6.059800
# 1       0.024469
# 2       2.491246
# 3       0.547374
# 4       1.878468

# %%
if backtest_df.empty:
    print('No backtest rows available. Check BACKTEST_YEAR and prediction files.')
else:
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.scatterplot(
        data=backtest_df,
        x='predicted_points_adj',
        y='actual_points',
        hue='position',
        alpha=0.35,
        s=20,
        ax=ax,
        palette='Set2',
    )

    max_axis = max(backtest_df['predicted_points_adj'].max(), backtest_df['actual_points'].max(), 1)
    ax.plot([0, max_axis], [0, max_axis], linestyle='--', color='black', linewidth=1)
    ax.set_title(f'Predicted vs Actual Points Across All Available GWs')
    ax.set_xlabel('Predicted points (adjusted)')
    ax.set_ylabel('Actual points')
    plt.tight_layout()

    if EXPORT_FIGURES:
        fig.savefig(FIG_DIR / 'pred_vs_actual_all_gws.png', dpi=200)

# %%
if backtest_df.empty:
    print('No backtest rows available. Skipping GW metric plots.')
else:
    gw_metrics = (
        backtest_df.groupby('gw', as_index=False)
        .agg(
            mae_raw=('abs_error_raw', 'mean'),
            mae_adj=('abs_error_adj', 'mean'),
            rmse_raw=('error_raw', lambda x: np.sqrt(np.mean(np.square(x)))),
            rmse_adj=('error_adj', lambda x: np.sqrt(np.mean(np.square(x)))),
            corr_adj=('predicted_points_adj', lambda x: x.corr(backtest_df.loc[x.index, 'actual_points'])),
            n_players=('full_name', 'count'),
        )
    )

    display(gw_metrics)

    fig, ax = plt.subplots(figsize=(10, 5))
    sns.lineplot(data=gw_metrics, x='gw', y='mae_raw', marker='o', label='MAE raw', ax=ax)
    sns.lineplot(data=gw_metrics, x='gw', y='mae_adj', marker='o', label='MAE adjusted', ax=ax)
    sns.lineplot(data=gw_metrics, x='gw', y='rmse_raw', marker='o', label='RMSE raw', ax=ax, linestyle='--')
    sns.lineplot(data=gw_metrics, x='gw', y='rmse_adj', marker='o', label='RMSE adjusted', ax=ax, linestyle='--')
    ax.set_title('Prediction Error by GW')
    ax.set_xlabel('GW')
    ax.set_ylabel('Error (points)')
    plt.tight_layout()

    if EXPORT_FIGURES:
        fig.savefig(FIG_DIR / 'prediction_error_by_gw.png', dpi=200)
# Out:
#     gw   mae_raw   mae_adj  rmse_raw  rmse_adj  corr_adj  n_players
# 0    2  1.398942  3.031277  2.290521  7.130428  0.128786        688
# 1    3  1.367993  1.751509  2.044060  3.369252  0.237116        704
# 2    4  1.374622  1.598399  2.056003  2.816350  0.386894        711
# 3    5  1.274219  1.544102  1.905574  2.917723  0.316065        739
# 4    6  1.233781  1.430650  1.938378  2.333200  0.442224        740
# 5    7  1.288138  1.448172  1.965947  2.374257  0.428807        741
# 6    8  1.335244  1.444678  2.145013  2.361295  0.472751        742
# 7    9  1.294102  1.432641  2.076107  3.082161  0.299649        744
# 8   10  1.300248  1.452354  1.942554  2.234027  0.480215        745
# 9   11  1.348842  1.476944  2.078492  2.306451  0.465562        746
# 10  12  1.347435  1.404799  2.141318  2.265945  0.473616        752
# 11  13  1.350426  1.362010  2.098252  2.115648  0.503346        755
# 12  14  1.399474  1.444088  2.229214  2.325084  0.453754        755
# 13  15  1.315039  1.347280  2.013053  2.039544  0.577658        758
# 14  16  1.357229  1.459983  2.138896  2.252360  0.509961        759
# 15  17  1.382487  1.385650  2.118162  2.102245  0.518821        760
# 16  18  1.319290  1.366153  2.045088  2.158195  0.453978        770
# 17  19  1.395254  1.447123  2.085054  2.230717  0.431534        775
# 18  20  1.330595  1.388923  2.041058  2.187429  0.463490        780
# 19  21  1.305626  1.356163  1.914314  2.025799  0.515041        790
# 20  22  1.351747  1.484584  1.902374  2.120985  0.416415        795
# 21  23  1.388491  1.434659  1.991765  2.077945  0.468225        799
# 22  24  1.334233  1.367204  2.000883  2.061937  0.510129        803
# 23  25  1.303343  1.346429  1.924305  2.007866  0.527450        811
# 24  26  1.386172  1.429298  2.163159  2.221922  0.501688        860
# 25  27  1.309528  1.370846  1.971636  2.017622  0.557364        896
# 26  28  1.317017  1.357802  1.948818  2.028686  0.495976        818
# 27  29  1.319793  1.385921  1.944806  2.092009  0.509387        819
# 28  30  1.341578  1.427624  1.934482  2.138294  0.441145        820
# 29  31  1.326086  1.406822  1.961812  2.129105  0.487990        661
# 30  32  1.316751  1.431753  2.058939  2.237454  0.434905        503
# 31  33  1.519244  1.581303  2.472082  2.636986  0.538538        963
# 32  34  1.093366  1.140580  1.878769  1.957206  0.511201        581
# 33  35  1.069010  1.037411  1.907037  1.893696  0.518276        830
# 34  36  1.198270  1.243691  2.233734  2.265357  0.559422        914
# 35  37  1.026767  1.058222  1.821626  1.848478  0.567462        838

# %% [markdown]
# ### What Is corr_adj?
#
# `corr_adj` is the Pearson correlation between `predicted_points_adj` and `actual_points` within each GW.
#
# - `corr_adj` near `1.0`: your model ranked players very well that week.
# - `corr_adj` near `0.0`: weak relationship between predictions and outcomes.
# - `corr_adj` below `0.0`: rankings were directionally wrong that week.
#
# This is most useful for judging ranking quality, not absolute error size.

# %%
if backtest_df.empty:
    print('No backtest rows available. Skipping corr_adj plot.')
else:
    corr_plot_df = gw_metrics[['gw', 'corr_adj']].dropna().copy()

    fig, ax = plt.subplots(figsize=(10, 4))
    sns.lineplot(data=corr_plot_df, x='gw', y='corr_adj', marker='o', ax=ax, color='#1f77b4')
    ax.axhline(0, color='black', linestyle='--', linewidth=1)
    ax.axhline(0.5, color='green', linestyle=':', linewidth=1)
    ax.axhline(0.3, color='orange', linestyle=':', linewidth=1)
    ax.set_ylim(-1, 1)
    ax.set_title('GW-by-GW corr_adj (Predicted Adj vs Actual)')
    ax.set_xlabel('GW')
    ax.set_ylabel('corr_adj (Pearson r)')
    plt.tight_layout()

    display(corr_plot_df)

    if EXPORT_FIGURES:
        fig.savefig(FIG_DIR / 'corr_adj_by_gw.png', dpi=200)
# Out:
#     gw  corr_adj
# 0    2  0.128786
# 1    3  0.237116
# 2    4  0.386894
# 3    5  0.316065
# 4    6  0.442224
# 5    7  0.428807
# 6    8  0.472751
# 7    9  0.299649
# 8   10  0.480215
# 9   11  0.465562
# 10  12  0.473616
# 11  13  0.503346
# 12  14  0.453754
# 13  15  0.577658
# 14  16  0.509961
# 15  17  0.518821
# 16  18  0.453978
# 17  19  0.431534
# 18  20  0.463490
# 19  21  0.515041
# 20  22  0.416415
# 21  23  0.468225
# 22  24  0.510129
# 23  25  0.527450
# 24  26  0.501688
# 25  27  0.557364
# 26  28  0.495976
# 27  29  0.509387
# 28  30  0.441145
# 29  31  0.487990
# 30  32  0.434905
# 31  33  0.538538
# 32  34  0.511201
# 33  35  0.518276
# 34  36  0.559422
# 35  37  0.567462
